# %%
from ultralytics import YOLO

model = YOLO('best.pt')

results = model('/Users/sachinkarthikeya/Downloads/Capstone Project/SOD-SSS-5/train/images/10715_bmp.rf.605f896a34dce3504c3063a57bde45eb.jpg')
results[0].show()
# Out:
# image 1/1 /Users/sachinkarthikeya/Downloads/Capstone Project/SOD-SSS-5/train/images/10715_bmp.rf.605f896a34dce3504c3063a57bde45eb.jpg: 640x640 1 Weapons, 96.3ms
# Speed: 1.5ms preprocess, 96.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="apUiV7snDplgUzUnTj5Y")
project = rf.workspace("small-object-detections-smart-surveillance-system").project("cgi-weapon-dataset-q6mia")
version = project.version(1)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in CGI-Weapon-Dataset-1 to coco:: 100%|██████████| 8167/8167 [00:02<00:00, 2854.29it/s]
# Extracting Dataset Version Zip to CGI-Weapon-Dataset-1 in coco:: 100%|██████████| 248/248 [00:00<00:00, 5017.69it/s]
